# %% [markdown]
# <a href="https://colab.research.google.com/github/technerd21/CV_Assign_FA19-BCS-001/blob/main/IDS_WebScrapper_FA19_BCS_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
#use BeautifulSoup and html5lib to parse HTML text

response = requests.get("https://news.sky.com/")
root = BeautifulSoup(response.content, 'html5lib')

#prettify() is used to format HTML text with proper indents
print(root.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="Sky News: Breaking, UK &amp; World" name="smartbanner:title"/>
#   <meta content="Sky UK Limited" name="smartbanner:author"/>
#   <meta content="FREE" name="smartbanner:price"/>
#   <meta content=" - On the App Store" name="smartbanner:price-suffix-apple"/>
#   <meta content=" - In Google Play" name="smartbanner:price-suffix-google"/>
#   <meta content="https://e0.365dm.com/skynews/apple-touch-icon.png" name="smartbanner:icon-apple"/>
#   <meta content="https://e0.365dm.com/skynews/apple-touch-icon.png" name="smartbanner:icon-google"/>
#   <meta content="VIEW" name="smartbanner:button"/>
#   <meta content="https://apps.apple.com/gb/app/sky-news-breaking-uk-world/id316391924" name="smartbanner:button-url-apple"/>
# ...

# %%
#use a loop to parse through HTML text and get to the data you want to extract
#it will filter out all the tags and data you do not need

for row in root.find_all('span', attrs = {'class':'sdc-site-tile__headline-text'}):
  print (row.text)
# Out:
# Man with knife dies after being shot by armed officers in police station car park
# Tory minister Conor Burns sacked with 'immediate effect' after complaint of serious misconduct
# Iran protests 'bring back memories' of helplessness of six years in prison
# 'Serious injuries' as major incident declared after explosion at service station in Ireland
# Effigy of Putin burned near Moscow; no response to Biden's Cuban Missile Crisis remark; will Russian capital cancel Christmas? Ukraine latest
# Entire police department at centre of Texas school shooting suspended
# Sturgeon attacks 'utterly catastrophic' Truss; Poll shows Tories would lose all London seats; NI protocol progress | Politics latest
# COVID-19 cases in UK leap by 25% with big rise among over-70s in England
# 'Obnoxious teenage troublemaker' detained for life for stabbing to death father-of-three
# Torches not candles and write down emergency numbers: How to prepare for a blackout
# ...
